# %%
import pandas as pd
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Python_variables.xlsx", \
                 header = 0)

# %%
df
# Out:
#       Month  nieuwe baan   CV  vacatures  uwv  werkloosheid  werkloos
# 0   2010-01           55  100         86   49            67        67
# 1   2010-02           65  100         88   56            71        54
# 2   2010-03           63   77         88   56            85        71
# 3   2010-04           58   64         81   49            59        36
# 4   2010-05           43   62         74   45            52        44
# 5   2010-06            6   63         79   52            59        53
# 6   2010-07           66   57         70   51            25        42
# 7   2010-08           73   64         81   51            22        46
# 8   2010-09           76   86         86   51            38        59
# 9   2010-10           59   82         81   50            56        54
# 10  2010-11           56   88         80   53            45        55
# 11  2010-12           65   77         63   50            42        53
# ...

# %%
df1 = pd.read_excel("Unemployment CBS.xlsx", \
                 header = 0)

# %%
df1
# Out:
#    Arbeidsdeelname en werkloosheid per maand      Unnamed: 1  \
# 0                                        NaN     Onderwerpen
# 1                                        NaN     Onderwerpen
# 2                                        NaN        Leeftijd
# 3                                   Geslacht        Perioden
# 4                                     Totaal    2010 januari
# 5                                     Totaal   2010 februari
# 6                                     Totaal      2010 maart
# 7                                     Totaal      2010 april
# 8                                     Totaal        2010 mei
# 9                                     Totaal       2010 juni
# 10                                    Totaal       2010 juli
# 11                                    Totaal   2010 augustus
# 12                                    Totaal  2010 september
# 13                                    Totaal    2010 oktober
# ...

# %%
df11 = df1.drop(["Arbeidsdeelname en werkloosheid per maand"], axis=1)
dfonlyper2 = df11.drop(["Unnamed: 2", "Unnamed: 3"], axis=1)
dfonlyper2.rename(columns={"Unnamed: 1": "Date"})
dfonlyper2.rename(columns={"Unnamed: 4": "Percentage"})
dfonlyper2 = dfonlyper2.drop(dfonlyper2.index[[0, 1, 2, 3]])

# %%
df11
# Out:
#         Unnamed: 1                 Unnamed: 2                 Unnamed: 3  \
# 0      Onderwerpen  Werkloze beroepsbevolking  Werkloze beroepsbevolking
# 1      Onderwerpen  Werkloze beroepsbevolking        Seizoengecorrigeerd
# 2         Leeftijd             15 tot 75 jaar             15 tot 75 jaar
# 3         Perioden                     x 1000                     x 1000
# 4     2010 januari                        467                        444
# 5    2010 februari                        475                        443
# 6       2010 maart                        470                        440
# 7       2010 april                        442                        432
# 8         2010 mei                        433                        434
# 9        2010 juni                        427                        434
# 10       2010 juli                        410                        438
# 11   2010 augustus                        406                        437
# ...

# %%
percentage = dfonlyper2.ix[:,1]
type(percentage)
# Out:
# pandas.core.series.Series

# %%
trace = Scatter(y=percentage, mode= 'lines', name = 'lines')
py.iplot([trace], filename='plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ManonWaals/15.embed" height="525px" width="100%"></iframe>
